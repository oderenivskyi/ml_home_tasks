# %% [markdown]
# ### Домашні завдання на відпрацювання поняття функції та її похідної
#
# 1. Задана функція залежності оцінки від кількості годин, витрачених на навчання: $ f(x) = 10x - 5 $.
#   1. З допомогою Python обчисліть похідну цієї функції.
#   2. Використовуйте бібліотеку `matplotlib` для побудови графіків функції та її похідної в діапазоні значень від 0 до 10 годин. Проаналізуйте, як зміна кількості годин вивчення впливає на оцінку.

# %%
import matplotlib.pyplot as plt
import sympy as sp
import numpy as np

# %%
x_symb = sp.symbols('x')

# %%
f_symb = 10 * x_symb - 5

derivative_f_symb = sp.diff(f_symb, x_symb)

print("Похідна функції", f_symb, "=", derivative_f_symb)
# Out:
# Похідна функції 10*x - 5 = 10

# %%
# Визначення функції та її похідної
x = np.linspace(0, 10, 100)
f = 10 * x - 5
derivative_f = np.full_like(x, 10)

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, f, label='f(x) = 10*x - 5', color='blue')
plt.plot(x, derivative_f, label="f'(x) = 10", color='green')

# Додавання легенди, міток та заголовка
plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **ДОДАТИ ТЕКСТ**

# %% [markdown]
# 2. Використовуючи Python і `SymPy`, обчисліть похідні для функцій $ f(x) = \sin(x) $ та $ f(x) = \ln(x) $. Зобразіть ці функції та їхні похідні за допомогою `matplotlib`.

# %%
f_sin_symb = sp.sin(x_symb)

derivative_f_sin_symb = sp.diff(f_sin_symb, x_symb)

print('Для функції', f_sin_symb, 'похідна буде', derivative_f_sin_symb)
# Out:
# Для функції sin(x) похідна буде cos(x)

# %%
x1 = np.linspace(0, 10, 100)
f1 = np.sin(x)
df1 = np.cos(x)

# %%
plt.figure(figsize=(10, 5))
plt.plot(x1, f1, label='f(x) = sin(x)', color='red')
plt.plot(x1, df1, label="f'(x) = cos(x)", color='green')

plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()

# %%
f_ln_symb = sp.ln(x_symb)

derivative_f_ln_symb = sp.diff(f_ln_symb, x_symb)

print('Для функції', f_ln_symb, 'похідна буде', derivative_f_ln_symb)
# Out:
# Для функції log(x) похідна буде 1/x

# %%
x2 = np.linspace(0.1, 10, 100)

f2 = np.log(x)

df2 = 1 / x
# Out:
# <ipython-input-54-3099681973>:3: RuntimeWarning: divide by zero encountered in log
#   f2 = np.log(x)
# <ipython-input-54-3099681973>:5: RuntimeWarning: divide by zero encountered in divide
#   df2 = 1 / x

# %%
plt.figure(figsize=(10, 5))
plt.plot(x2, f2, label='f(x) = sin(x)', color='red')
plt.plot(x2, df2, label="f'(x) = cos(x)", color='green')

plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# 3. Загальні витрати компанії від обсягу виробництва задані функцією $ f(x) = x^2 - 5x + 1 $, де $ x $ — кількість вироблених одиниць. Обчисліть похідну цієї функції з допомогою SymPy та візуалізуйте значення функції і її похідної на відрізку від 0 до 100.

# %%
f_prod_symb = x_symb ** 2 - 5 * x_symb + 1

df_prod_symb = sp.diff(f_prod_symb, x_symb)

print('Для функції', f_prod_symb, 'похідна буде', df_prod_symb)
# Out:
# Для функції x**2 - 5*x + 1 похідна буде 2*x - 5

# %%
x_prod = np.linspace(0, 100, 100)

f_prod = x ** 2 - 5 * x + 1

df_prod = 2 * x - 5

# %%
plt.figure(figsize=(10, 5))
plt.plot(x_prod, f_prod, label='f(x) = x ** 2 - 5 * x + 1', color='red')
plt.plot(x_prod, df_prod, label="f'(x) = 2 * x - 5", color='green')

plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()
