# %% [markdown]
# # Розділ 1

# %% [markdown]
# ## Підрозділ 1

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
a = 2
b = 5
c = 34

# %%
d = a + b + c

print(d)
# Out:
# 41

# %%
m = b / c

# %%
print(m)
# Out:
# 0.14705882352941177
